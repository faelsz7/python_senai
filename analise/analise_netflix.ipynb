# %% [markdown]
# # Analise exploratoria de top 10 do catalogo Netflix
#
# Analisaremos a seguir uma base de dados do catalogo Netflix, com intuito de entender quais produtos do seu catalogo alcançaram o top 10 mais assistidos da plataforma para fins de estudos e aprendizado da biblioteca "pandas".

# %%
# Instalando a biblioteca de analise de dados pandas

# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#carregando o dataframe na memoria.
df_netflix = pd.read_csv("netflix daily top 10.csv", sep=",")
#nao sei pra que funciona esse comando :)

# %%
#visualisando as primeiras linhas do dataframe
df_netflix.head()
# Out:
#         As of  Rank Year to Date Rank Last Week Rank  \
# 0  2020-04-01     1                 1              1
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
#
#                           Title     Type Netflix Exclusive  \
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score
# 0         Mar 20, 2020               9                90
# 1         Jul 21, 2017               5                45
# 2         Mar 28, 2019               9                76
# ...

# %%
#analisando o final da lista
df_netflix.tail()
# Out:
#            As of  Rank Year to Date Rank Last Week Rank                Title  \
# 7095  2022-03-11     6                 5              1  Worst Roommate Ever
# 7096  2022-03-11     7                 7              2    Vikings: Valhalla
# 7097  2022-03-11     8                 8              -              Shooter
# 7098  2022-03-11     9                 9              7              Shrek 2
# 7099  2022-03-11    10                10              -                Shrek
#
#          Type Netflix Exclusive Netflix Release Date  Days In Top 10  \
# 7095  TV Show               Yes          Mar 1, 2022              10
# 7096  TV Show               Yes         Feb 25, 2022              14
# 7097    Movie               NaN          Aug 1, 2014               3
# 7098    Movie               NaN          Mar 1, 2022              10
# 7099    Movie               NaN          May 1, 2018               7
#
#       Viewership Score
# 7095                81
# 7096               100
# ...

# %%
#ahhhh aqui ele coloca os 5 primeiros e 5 ultimos da lista (nao reconmendavel)
display(df_netflix)
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 0     2020-04-01     1                 1              1
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# ...

# %%
# Verificando tamanho do dataframe

df_netflix.shape
# Out:
# (7100, 10)

# %%
# Informacoes individuais de cada coluna no dataframe, com base em seu tipo,
#nome e quantidade de registros
df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   object
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   object
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 554.8+ KB

# %%
#verificamos uma coluna especifica de um dataframe e analisamos a quantidadede nulos totais presentes
df_netflix["Netflix Exclusive"].isnull().sum()
df_netflix["Netflix Exclusive"].isnull()
#o sem sum e pra analisar todas as colunas e com sum para somar todos os nulos
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 7095    False
# 7096    False
# 7097     True
# 7098     True
# 7099     True
# Name: Netflix Exclusive, Length: 7100, dtype: bool

# %%
df_netflix['Netflix Exclusive'].value_counts()
# Out:
# Netflix Exclusive
# Yes    4599
# Name: count, dtype: int64

# %%
#biblioteca para plotagem e graficos

# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_netflix.plot(kind='box', figsize=(16, 16), subplots=True );

# %%
df_netflix.hist()
# Out:
# array([[<Axes: title={'center': 'Rank'}>,
#         <Axes: title={'center': 'Days In Top 10'}>],
#        [<Axes: title={'center': 'Viewership Score'}>, <Axes: >]],
#       dtype=object)

# %%
def aplica_no(exclusive):
    if exclusive != 'Yes':
        return 'No'
    return exclusive

# %%
df_netflix['Netflix Exclusive'] = df_netflix['Netflix Exclusive'].apply(aplica_no)

# %%
print(df_netflix)
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 0     2020-04-01     1                 1              1
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show                No
# ...

# %%
df_netflix.drop('Last Week Rank',axis=1)
# Out:
#            As of  Rank Year to Date Rank                         Title  \
# 0     2020-04-01     1                 1  Tiger King: Murder, Mayhem …
# 1     2020-04-01     2                 2                         Ozark
# 2     2020-04-01     3                 3                  All American
# 3     2020-04-01     4                 4                  Blood Father
# 4     2020-04-01     5                 5                  The Platform
# ...          ...   ...               ...                           ...
# 7095  2022-03-11     6                 5           Worst Roommate Ever
# 7096  2022-03-11     7                 7             Vikings: Valhalla
# 7097  2022-03-11     8                 8                       Shooter
# 7098  2022-03-11     9                 9                       Shrek 2
# 7099  2022-03-11    10                10                         Shrek
#
#          Type Netflix Exclusive Netflix Release Date  Days In Top 10  \
# ...
